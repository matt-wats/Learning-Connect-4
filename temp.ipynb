# %%
import torch

import numpy as np

import Board
import Evaluator
import Search
import Play
import Train

import matplotlib.pyplot as plt

# %%
evaluator = Evaluator.Evaluator()
optimizer = torch.optim.AdamW(evaluator.parameters(), lr=1e-4)

# %%
epochs = 45*30
losses = Train.train(evaluator, epochs, optimizer)

# %%
plt.semilogy(losses)

# %%
np.min(losses)
# Out:
# 0.2316102236509323

# %%
positions, score = Play.play_game(evaluator)
